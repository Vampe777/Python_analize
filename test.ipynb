# %% [markdown]
# # Игра угадай число

# %% [markdown]
# ## Угадываем рандомно

# %%
from test2 import score_game
from test2 import random_predict

# %%
score_game(random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 484 попыток
# 484
